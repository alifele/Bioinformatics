# %% [markdown]
# <a href="https://colab.research.google.com/github/alifele/Bioinformatics-OpticalCNNwithFourierOptics/blob/master/FFT_first_attempt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import jv
from scipy import signal
from scipy import misc
from sklearn.datasets import load_sample_image
import scipy

# %%
def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.299, 0.587, 0.144])

# %%
flower = load_sample_image("flower.jpg") / 255
flower =  rgb2gray(flower)
flower.shape
# Out:
# (427, 640)

# %%
plt.imshow(flower, cmap='gray')

# %%
Flower = np.fft.fft2(flower)
#Flower = np.abs(Flower)

# %%
plt.imshow(Flower[0:10,0:10].real)
plt.colorbar()

# %%
plt.imshow(Flower.imag)

# %%
Flower.shape
# Out:
# (427, 640)

# %%
plt.plot(Flower[:,10].real)

# %%
Flower.real.max()
# Out:
# 72750.30464705882

# %%
plt.imshow(np.abs(Flower))

# %%
x = np.arange(0,10,0.1)
y = np.sin(x)
X = np.fft.fft(y)
plt.plot(x,y)

# %%
plt.plot(x,X)
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
plt.plot(np.fft.fft(np.random.randn(1000)).real)

# %%
a = np.random.random(2500).reshape((50,50))
A = np.fft.fft2(a)
plt.figure(figsize=(12,12))
plt.imshow(A.real)

# %%
FS = np.fft.fftn(flower)
plt.figure(figsize=(15,15))
fft_shift = np.fft.fftshift(FS)
plt.imshow(np.log(np.abs(fft_shift)**2))
plt.figure(figsize=(15,15))
plt.imshow(np.log(np.abs(FS)**2))
#FS = FS[0:int(FS.shape[0]/2),0:int(FS.shape[1]/2)]
#plt.imshow(np.log(np.abs(FS)**2))
plt.show()

# %%
fft_FS = np.fft.fftn(FS)
#fft_FS_shift = np.fft.fftshift(fft_FS)
plt.imshow(np.log(np.abs(fft_FS)**2))

# %%
fft_FS_shift = np.fft.fftn(fft_shift)
#fft_FS_shift_shift = np.fft.fftshift(fft_FS_shift)
plt.imshow(np.log(np.abs(fft_FS_shift)**2))

# %%
x_len = flower.shape
# Out:
# (427, 640)

# %%
x = np.linspace(-10,10,200)
X,Y = np.meshgrid(x,x)
Sin = np.sin(X)
plt.contourf(X,Y,Sin)

# %%
plt.figure(figsize=(10,10))
fft_Sin = np.fft.fftn(Sin)
plt.imshow(np.abs(fft_Sin)**2)

# %%
fft_Sin_scipy = scipy.fft.fft2(Sin)
#plt.imshow(np.log(np.abs(fft_Sin_scipy)))
plt.imshow(np.real(fft_Sin_scipy))
